# %% [markdown]
# # The Istanbul Metropolitan Municipality Car Park "ISPARK" Analysis <br>
# *Prepared by Evren Ermis based the data from https://data.ibb.gov.tr/*
# ***

# %%
ispark_logo = plt.imread("ispark_logo.png")
plt.imshow(ispark_logo)

# %% [markdown]
# ## 1 - Business Understanding

# %% [markdown]
# In this project, ISPARK - Istanbul Park, municipally driven car park company, data has used to analyze Istanbul car park status including cost, usage and location.

# %% [markdown]
# In this project; I try to find out the answers of below questions <br>
#
#    - How many parking points do each side of Istanbul have ? What is the number of parking points and their monthly cost over district in Istanbul ?
#
#    - What is the utilization rate and capacity of parking points per district in Istanbul ?
#
#    - What are the parking slots that we can stop 15 minutes freely ?
#
#    - Bonus: Create a map plot of parking points regarding their capacity, utilization rate and cost for better location and distribution understanding

# %% [markdown]
# ## 2 - Data Understanding

# %% [markdown]
# ### 2.1 - Data Load & Preprocessing

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_excel("ibb_ispark.xlsx", sheet_name="İSPARK Otoparklarına Ait B.", index_col = 0)

# %%
# Lower all columns and put "_" ilo " "

df.columns = df.columns.str.replace(" ", "_")
df.columns = map(str.lower, df.columns)

# %%
df.shape
# Out:
# (731, 23)

# %%
df["park_adı"].duplicated().sum()
# Out:
# 44

# %%
df.drop_duplicates(subset="park_adı", keep="first", inplace=True)

# %%
df.shape
# Out:
# (687, 23)

# %%
df.head()
# Out:
#                             park_adı  lokasyon_id  lokasyon_kodu  \
# Park ID
# 359                Atatürk Bulvarı 1          150              1
# 860      Bakırköy İstanbul Caddesi 1          384              2
# 861      Bakırköy İstanbul Caddesi 2          384              2
# 862      Bakırköy İstanbul Caddesi 3          384              2
# 867      Bakırköy İstanbul Caddesi 8          384              2
#
#                            lokasyon_adı  park_tipi_id park_tipi  \
# Park ID
# 359              0001 Atatürk Bulvarı 1             2  YOL ÜSTÜ
# 860      0002 Bakırköy İstanbul Caddesi             2  YOL ÜSTÜ
# 861      0002 Bakırköy İstanbul Caddesi             2  YOL ÜSTÜ
# 862      0002 Bakırköy İstanbul Caddesi             2  YOL ÜSTÜ
# 867      0002 Bakırköy İstanbul Caddesi             2  YOL ÜSTÜ
#
#          park_kapasitesi calışma_saatleri  bölge_id   bölge  ...     i̇lçe  \
# Park ID                                                      ...
# 359                   18      07:30-18:30         4  Avrupa  ...     FATİH
# 860                   30      08:00-19:00         4  Avrupa  ...  BAKIRKÖY
# 861                   30      08:00-19:00         4  Avrupa  ...  BAKIRKÖY
# 862                   70      08:00-19:00         4  Avrupa  ...  BAKIRKÖY
# 867                   40      08:00-19:00         4  Avrupa  ...  BAKIRKÖY
#
#                                                      adres  \
# Park ID
# 359        KEMALPAŞA MAHALLESİ ATATÜRK BULVARI 1 / EMİNÖNÜ
# 860      YEŞİLKÖY MAHALLESİ İSTANBUL CADDESİ ÜZERİ BAKI...
# 861      YEŞİLKÖY MAHALLESİ İSTANBUL CADDESİ ÜZERİ BAKI...
# 862      YEŞİLKÖY MAHALLESİ İSTANBUL CADDESİ ÜZERİ BAKI...
# 867      YEŞİLKÖY MAHALLESİ İSTANBUL CADDESİ ÜZERİ BAKI...
#
#                                           enlem/boylam  \
# Park ID
# 359      POINT (28.953538299155497 41.011291499669255)
# 860         POINT (28.8747420429072 40.97837155571149)
# 861       POINT (28.875321425593391 40.97841938898064)
# 862       POINT (28.87595720460348 40.978472523602171)
# 867      POINT (28.878947832742334 40.978643838182634)
#
#                                             polygon_verisi     boylam  \
# Park ID
# 359      MULTIPOLYGON (((28.95351077 41.01117896, 28.95...  28.953538
# 860      MULTIPOLYGON (((28.87445897 40.97835591, 28.87...  28.874742
# 861      MULTIPOLYGON (((28.87546464 40.97842251, 28.87...  28.875321
# 862      MULTIPOLYGON (((28.87628195 40.9784853, 28.876...  28.875957
# 867      MULTIPOLYGON (((28.87909771 40.97868195, 28.87...  28.878948
#
#              enlem aylık_abonelik_ücreti  ücretsiz_parklanma_süresi_(dakika)  \
# Park ID
# 359      41.011291                   0.0                                15.0
# 860      40.978372                 400.0                                15.0
# 861      40.978419                 400.0                                15.0
# 862      40.978473                 400.0                                15.0
# 867      40.978644                 400.0                                15.0
#
#                                                   tarifesi  \
# Park ID
# 359      0-1 Saat  : 10,00;1-2 Saat  : 11,00;2-4 Saat  ...
# 860      0-1 Saat  : 10,00;1-2 Saat  : 12,00;2-4 Saat  ...
# 861      0-1 Saat  : 10,00;1-2 Saat  : 12,00;2-4 Saat  ...
# 862      0-1 Saat  : 10,00;1-2 Saat  : 12,00;2-4 Saat  ...
# 867      0-1 Saat  : 10,00;1-2 Saat  : 12,00;2-4 Saat  ...
#
#          park_et_devam_et_noktası
# Park ID
# 359                             0
# 860                             0
# 861                             0
# 862                             0
# 867                             0
#
# [5 rows x 23 columns]

# %% [markdown]
# ### 2.2 - Side & District Analysis by Park Count and Monthly Price

# %%
side_name = df.groupby("bölge")["lokasyon_id"].count().sort_values(ascending=False).index
side_park_count = df.groupby("bölge")["lokasyon_id"].count().sort_values(ascending=False).values

fig = plt.figure(figsize=(6,6))
ax = fig.add_axes([0,0,1,1])
ax.axis('equal')
explode = (0,0.1)
colors = ["navy","indianred"]
labels = side_name
values = side_park_count
_,_, autotexts = ax.pie(side_park_count, labels = labels,autopct='%1.2f%%', 
                        shadow=True, explode = explode, colors=colors)
for autotext in autotexts:
    autotext.set_color('white')

plt.title("Side - #Parking Point Breakdown")    
plt.show()

print("Actual values =\n" + str(df.groupby("bölge")["lokasyon_id"].count().sort_values(ascending=False)))
# Out:
# Actual values =
# bölge
# Avrupa     482
# Anadolu    205
# Name: lokasyon_id, dtype: int64

# %% [markdown]
# Apparently eu side has 2x car park count of anatolian side

# %%
# Lets split our data into sides of Istanbul to illustrate district's car park count and average monthly cost

df_avp = df[df["bölge"]=="Avrupa"]
df_and = df[df["bölge"]=="Anadolu"]

# European Side dataframe creation
avp_location = df_avp.groupby("i̇lçe")["lokasyon_id"].count().index
avp_count = df_avp.groupby("i̇lçe")["lokasyon_id"].count().values
avp_cost = df_avp.groupby("i̇lçe")["aylık_abonelik_ücreti"].mean().round(0).values
df_avp_final = pd.DataFrame({"location": avp_location, "park_count": avp_count, "park_avg_monthly_cost":avp_cost})

# Anatolian Side dataframe creation
and_location = df_and.groupby("i̇lçe")["lokasyon_id"].count().index
and_count = df_and.groupby("i̇lçe")["lokasyon_id"].count().values
and_cost = df_and.groupby("i̇lçe")["aylık_abonelik_ücreti"].mean().round(0).values
df_and_final = pd.DataFrame({"location": and_location, "park_count": and_count, "park_avg_monthly_cost":and_cost})

# %%
# Anatolian Side district car park count and cost breakdown
fig, ax = plt.subplots(figsize=(20,8))

x = np.arange(len(df_and_final["location"]))
width = 0.40 # width of bar

xs = df_and_final["location"]
ys_1 = df_and_final["park_count"]
ys_2 = df_and_final["park_avg_monthly_cost"]


ax.bar(x, ys_1, color= "indianred", align='center', width=width, label="Park Count")
ax.bar(x + width , ys_2, color= "darkblue", align='center', width=width, label="Avg. Monthly Cost")

ax.set_title("Istanbul Anatolian Side Car Park Count and Cost Breakdown")
ax.set_xlabel('District')
ax.set_ylabel('Count / Cost')

ax.set_xticklabels(xs)
ax.set_xticks(x + width)
ax.tick_params(rotation=45)

# Annotation link: https://stackoverflow.com/questions/43554521/add-data-label-to-grouped-bar-chart-in-matplotlib
for p in ax.patches[1:]:
    h = p.get_height()
    x = p.get_x()+p.get_width()/2.
    if h != 0:
        ax.annotate("%g" % p.get_height(), xy=(x,h), xytext=(0,4), 
                   textcoords="offset points", ha="center", va="bottom")

ax.legend(loc="upper right", fontsize="large")
plt.show()

# %%
# Anatolian Side district car park count and cost breakdown
fig, ax = plt.subplots(figsize=(20,8))

x = np.arange(len(df_avp_final["location"]))
width = 0.40 # width of bar

xs = df_avp_final["location"]
ys_1 = df_avp_final["park_count"]
ys_2 = df_avp_final["park_avg_monthly_cost"]


ax.bar(x, ys_1, color= "indianred", align='center', width=width, label="Park Count")
ax.bar(x + width , ys_2, color= "darkblue", align='center', width=width, label="Avg. Monthly Cost")

ax.set_title("Istanbul European Side Car Park Count and Cost Breakdown")
ax.set_xlabel('District')
ax.set_ylabel('Count / Cost')

ax.set_xticklabels(xs)
ax.set_xticks(x + width)
ax.tick_params(rotation=45)

# Annotation link: https://stackoverflow.com/questions/43554521/add-data-label-to-grouped-bar-chart-in-matplotlib
for p in ax.patches[1:]:
    h = p.get_height()
    x = p.get_x()+p.get_width()/2.
    if h != 0:
        ax.annotate("%g" % p.get_height(), xy=(x,h), xytext=(0,4), 
                   textcoords="offset points", ha="center", va="bottom")

ax.legend(loc="upper left", fontsize="large")
plt.show()

# %%
df["enlem"].describe()
# Out:
# count    579.000000
# mean      40.998477
# std        0.508941
# min       28.854073
# 25%       40.992252
# 50%       41.020753
# 75%       41.055416
# max       41.196793
# Name: enlem, dtype: float64

# %%
df["boylam"].describe()
# Out:
# count    578.000000
# mean      28.981857
# std        0.149553
# min       28.243480
# 25%       28.945452
# 50%       28.993763
# 75%       29.039414
# max       29.326817
# Name: boylam, dtype: float64

# %%
df[round(df["enlem"])==29].index
# Out:
# Int64Index([2455], dtype='int64', name='Park ID')

# %%
df.drop(df[round(df["enlem"])==29].index, inplace=True)

# %%
info = ((df["boylam"].min(), df["boylam"].max(),
         df["enlem"].min(),   df["enlem"].max()))
        
info
# Out:
# (28.2434800707908, 29.3268173933029, 40.8150088134286, 41.1967928344884)

# %% [markdown]
# ## 2.3 - Live Status of ISPARK - Car Parking Lots

# %%
import requests

# %%
r = requests.get("https://api.ibb.gov.tr/ispark/Park")

# %%
df_live = pd.DataFrame.from_dict(r.json())

# %%
df_live.columns = df_live.columns.str.replace(" ", "_")
df_live.columns = map(str.lower, df_live.columns)

# %%
df_live.shape
# Out:
# (602, 10)

# %%
df_live["parkadi"].duplicated().sum()
# Out:
# 23

# %%
df_live.drop_duplicates(subset="parkadi", keep="first", inplace=True)

# %%
df_live.shape
# Out:
# (579, 10)

# %%
df_live.head()
# Out:
#    parkid                                           parkadi          latitude  \
# 0     395                                Yeşil Vadi Sokak 4  40.9670716467854
# 1    1189                         İçerenköy Açık Otoparkı 1  40.9765973901075
# 2    2151              Bostancı Vergi Dairesi Açık Otoparkı  40.9625308244579
# 4    1176                        Kozyatağı Sebze-Meyve Hali   40.978484297008
# 5    1208  Bostancı İdo ve Adalar İskelesi Önü Taksi Durağı   40.952526073751
#
#           longitude  kapasitesi  boskapasite      parktipi      ilce  \
# 0  29.1058243767132          40           27      YOL ÜSTÜ  ATAŞEHİR
# 1  29.1045454144478         600          599  AÇIK OTOPARK  ATAŞEHİR
# 2  29.1079999343615         105          105  AÇIK OTOPARK  ATAŞEHİR
# 4  29.1029469575332        1500         1500  AÇIK OTOPARK  ATAŞEHİR
# 5  29.0937899011629          16           16    TAKSİ PARK   KADIKÖY
#
#    distance  ucretsizparklanmadk
# 0     0.372                   15
# 1     0.696                   15
# 2     0.907                    0
# 4     0.918                    0
# 5     2.180                    0

# %%
# Calculate %Utilization per parking lot

df_live["utilization"] = (100 - (round((df_live["boskapasite"] / df_live["kapasitesi"])*100,0)))

# %%
df_live.head()
# Out:
#    parkid                                           parkadi          latitude  \
# 0     395                                Yeşil Vadi Sokak 4  40.9670716467854
# 1    1189                         İçerenköy Açık Otoparkı 1  40.9765973901075
# 2    2151              Bostancı Vergi Dairesi Açık Otoparkı  40.9625308244579
# 4    1176                        Kozyatağı Sebze-Meyve Hali   40.978484297008
# 5    1208  Bostancı İdo ve Adalar İskelesi Önü Taksi Durağı   40.952526073751
#
#           longitude  kapasitesi  boskapasite      parktipi      ilce  \
# 0  29.1058243767132          40           27      YOL ÜSTÜ  ATAŞEHİR
# 1  29.1045454144478         600          599  AÇIK OTOPARK  ATAŞEHİR
# 2  29.1079999343615         105          105  AÇIK OTOPARK  ATAŞEHİR
# 4  29.1029469575332        1500         1500  AÇIK OTOPARK  ATAŞEHİR
# 5  29.0937899011629          16           16    TAKSİ PARK   KADIKÖY
#
#    distance  ucretsizparklanmadk  utilization
# 0     0.372                   15         32.0
# 1     0.696                   15          0.0
# 2     0.907                    0          0.0
# 4     0.918                    0          0.0
# 5     2.180                    0          0.0

# %%
df_live[df_live["utilization"] >= 70].sort_values(by="kapasitesi", ascending=False).head(10)
# Out:
#      parkid                                  parkadi          latitude  \
# 477    1913      Alibeyköy Cep Otogarı Açık Otoparkı  41.0877898089066
# 503    2866              15 Temmuz Demokrasi Otogarı   41.041551975453
# 42     2808  Kadıköy Yeni Salı Pazarı Katlı Otoparkı  40.9977918776891
# 64     1328                         Eski Salı Pazarı  40.9907026712811
# 174    1473                            Karaköy Katlı  41.0230050497824
# 116    1474        Kartal Hasan Doğan Spor Kompleksi  40.8925343906162
# 7      1455                            Bostancı Açık  40.9522908984578
# 197    2194            Ragıp Gümüşpala Açık Otoparkı  41.0183951972286
# 193    1454                    Eminönü Açık Otoparkı  41.0192394608638
# 60     1470             Haldun Alagaş Katlı Otoparkı  41.0260703724597
#
#             longitude  kapasitesi  boskapasite        parktipi        ilce  \
# 477  28.9445382356644        5000          439    AÇIK OTOPARK        EYÜP
# 503  28.8945926849422        1907            0    AÇIK OTOPARK  BAYRAMPAŞA
# 42   29.0500764411344        1350            0  KAPALI OTOPARK     KADIKÖY
# 64   29.0333458664072         760           10    AÇIK OTOPARK     KADIKÖY
# 174  28.9773681581715         600            0  KAPALI OTOPARK     BEYOĞLU
# 116   29.189911589983         400            5  KAPALI OTOPARK      KARTAL
# 7    29.0902551716656         375           73    AÇIK OTOPARK     KADIKÖY
# 197  28.9692061013646         300           24    AÇIK OTOPARK       FATİH
# 193  28.9696684433955         280            0    AÇIK OTOPARK       FATİH
# 60   29.1050952305836         240           69  KAPALI OTOPARK    ÜMRANİYE
#
#      distance  ucretsizparklanmadk  utilization
# 477    18.750                   30         91.0
# 503    19.360                   60        100.0
# 42      5.519                   15        100.0
# 64      6.420                   20         99.0
# 174    12.200                   15        100.0
# 116    11.220                   15         99.0
# 7       2.344                   15         81.0
# 197    12.590                   15         92.0
# 193    12.590                   10        100.0
# 60      6.190                   15         71.0

# %%
# Graph to illustrate parking lots which have the highest capability (utilization >= 70)

plt.subplots(figsize=(12,6))

xs = df_live[df_live["utilization"] >= 70].sort_values(by="kapasitesi", ascending=False).head(10)["parkadi"].values
ys = df_live[df_live["utilization"] >= 70].sort_values(by="kapasitesi", ascending=False).head(10)["kapasitesi"].values

plt.bar(xs, ys, color="slateblue")
plt.xlabel('Car Park Name')
plt.ylabel('Capacity')
plt.title("The highest capacity parking lots in Istanbul (>=70% utilization)")
plt.xticks(rotation=90)

# annotation
for x,y in zip(xs,ys):

    label = "{:.2f}".format(y)

    plt.annotate(label, # this is the text
                 (x,y), # this is the point to label
                 textcoords="offset points", # how to position the text
                 xytext=(0,5), # distance from text to points (x,y)
                 ha='center') # horizontal alignment can be left, right or center
plt.show()

# %%
# Create a dataset contains avg utilization and parking lot capacity per district

df_district_capacity = pd.DataFrame({"location":df_live.groupby("ilce")["kapasitesi"].sum().index,
                                    "capacity":df_live.groupby("ilce")["kapasitesi"].sum().values})

df_district = pd.DataFrame({"location":df_live.groupby("ilce")["utilization"].mean().sort_values(ascending=False).index,
                            "avg_utilization": round(df_live.groupby("ilce")["utilization"].mean(),1).sort_values(ascending=False).values}
                          )

df_district = df_district.merge(df_district_capacity, on="location")
df_district.head(20).style.background_gradient(cmap='Greens')
# Out:
# <style  type="text/css" >
#     #T_0809daae_d0d5_11ea_8f4b_94f6d61f3bferow0_col1 {
#             background-color:  #00441b;
#             color:  #f1f1f1;
#         }    #T_0809daae_d0d5_11ea_8f4b_94f6d61f3bferow0_col2 {
#             background-color:  #f4fbf1;
#             color:  #000000;
#         }    #T_0809daae_d0d5_11ea_8f4b_94f6d61f3bferow1_col1 {
#             background-color:  #0e7936;
#             color:  #f1f1f1;
#         }    #T_0809daae_d0d5_11ea_8f4b_94f6d61f3bferow1_col2 {
#             background-color:  #f7fcf5;
#             color:  #000000;
#         }    #T_0809daae_d0d5_11ea_8f4b_94f6d61f3bferow2_col1 {
#             background-color:  #248c46;
#             color:  #000000;
#         }    #T_0809daae_d0d5_11ea_8f4b_94f6d61f3bferow2_col2 {
#             background-color:  #c1e6ba;
#             color:  #000000;
#         }    #T_0809daae_d0d5_11ea_8f4b_94f6d61f3bferow3_col1 {
#             background-color:  #58b668;
#             color:  #000000;
#         }    #T_0809daae_d0d5_11ea_8f4b_94f6d61f3bferow3_col2 {
#             background-color:  #e5f5e0;
#             color:  #000000;
#         }    #T_0809daae_d0d5_11ea_8f4b_94f6d61f3bferow4_col1 {
#             background-color:  #6bc072;
#             color:  #000000;
#         }    #T_0809daae_d0d5_11ea_8f4b_94f6d61f3bferow4_col2 {
#             background-color:  #ccebc6;
#             color:  #000000;
#         }    #T_0809daae_d0d5_11ea_8f4b_94f6d61f3bferow5_col1 {
#             background-color:  #6ec173;
#             color:  #000000;
#         }    #T_0809daae_d0d5_11ea_8f4b_94f6d61f3bferow5_col2 {
#             background-color:  #edf8ea;
#             color:  #000000;
#         }    #T_0809daae_d0d5_11ea_8f4b_94f6d61f3bferow6_col1 {
#             background-color:  #73c476;
#             color:  #000000;
#         }    #T_0809daae_d0d5_11ea_8f4b_94f6d61f3bferow6_col2 {
#             background-color:  #e8f6e3;
#             color:  #000000;
#         }    #T_0809daae_d0d5_11ea_8f4b_94f6d61f3bferow7_col1 {
#             background-color:  #78c679;
#             color:  #000000;
#         }    #T_0809daae_d0d5_11ea_8f4b_94f6d61f3bferow7_col2 {
#             background-color:  #c4e8bd;
#             color:  #000000;
#         }    #T_0809daae_d0d5_11ea_8f4b_94f6d61f3bferow8_col1 {
#             background-color:  #7dc87e;
#             color:  #000000;
#         }    #T_0809daae_d0d5_11ea_8f4b_94f6d61f3bferow8_col2 {
#             background-color:  #dbf1d6;
#             color:  #000000;
#         }    #T_0809daae_d0d5_11ea_8f4b_94f6d61f3bferow9_col1 {
#             background-color:  #91d28e;
#             color:  #000000;
#         }    #T_0809daae_d0d5_11ea_8f4b_94f6d61f3bferow9_col2 {
#             background-color:  #88ce87;
#             color:  #000000;
#         }    #T_0809daae_d0d5_11ea_8f4b_94f6d61f3bferow10_col1 {
#             background-color:  #9bd696;
#             color:  #000000;
#         }    #T_0809daae_d0d5_11ea_8f4b_94f6d61f3bferow10_col2 {
#             background-color:  #9cd797;
#             color:  #000000;
#         }    #T_0809daae_d0d5_11ea_8f4b_94f6d61f3bferow11_col1 {
#             background-color:  #9fd899;
#             color:  #000000;
#         }    #T_0809daae_d0d5_11ea_8f4b_94f6d61f3bferow11_col2 {
#             background-color:  #a2d99c;
#             color:  #000000;
#         }    #T_0809daae_d0d5_11ea_8f4b_94f6d61f3bferow12_col1 {
#             background-color:  #afdfa8;
#             color:  #000000;
#         }    #T_0809daae_d0d5_11ea_8f4b_94f6d61f3bferow12_col2 {
#             background-color:  #ebf7e7;
#             color:  #000000;
#         }    #T_0809daae_d0d5_11ea_8f4b_94f6d61f3bferow13_col1 {
#             background-color:  #bce4b5;
#             color:  #000000;
#         }    #T_0809daae_d0d5_11ea_8f4b_94f6d61f3bferow13_col2 {
#             background-color:  #f6fcf4;
#             color:  #000000;
#         }    #T_0809daae_d0d5_11ea_8f4b_94f6d61f3bferow14_col1 {
#             background-color:  #c7e9c0;
#             color:  #000000;
#         }    #T_0809daae_d0d5_11ea_8f4b_94f6d61f3bferow14_col2 {
#             background-color:  #d4eece;
#             color:  #000000;
#         }    #T_0809daae_d0d5_11ea_8f4b_94f6d61f3bferow15_col1 {
#             background-color:  #cdecc7;
#             color:  #000000;
#         }    #T_0809daae_d0d5_11ea_8f4b_94f6d61f3bferow15_col2 {
#             background-color:  #ddf2d8;
#             color:  #000000;
#         }    #T_0809daae_d0d5_11ea_8f4b_94f6d61f3bferow16_col1 {
#             background-color:  #e9f7e5;
#             color:  #000000;
#         }    #T_0809daae_d0d5_11ea_8f4b_94f6d61f3bferow16_col2 {
#             background-color:  #c1e6ba;
#             color:  #000000;
#         }    #T_0809daae_d0d5_11ea_8f4b_94f6d61f3bferow17_col1 {
#             background-color:  #ecf8e8;
#             color:  #000000;
#         }    #T_0809daae_d0d5_11ea_8f4b_94f6d61f3bferow17_col2 {
#             background-color:  #f5fbf2;
#             color:  #000000;
#         }    #T_0809daae_d0d5_11ea_8f4b_94f6d61f3bferow18_col1 {
#             background-color:  #f4fbf1;
#             color:  #000000;
#         }    #T_0809daae_d0d5_11ea_8f4b_94f6d61f3bferow18_col2 {
#             background-color:  #b0dfaa;
#             color:  #000000;
#         }    #T_0809daae_d0d5_11ea_8f4b_94f6d61f3bferow19_col1 {
#             background-color:  #f7fcf5;
#             color:  #000000;
#         }    #T_0809daae_d0d5_11ea_8f4b_94f6d61f3bferow19_col2 {
#             background-color:  #00441b;
#             color:  #f1f1f1;
#         }</style><table id="T_0809daae_d0d5_11ea_8f4b_94f6d61f3bfe" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >location</th>        <th class="col_heading level0 col1" >avg_utilization</th>        <th class="col_heading level0 col2" >capacity</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_0809daae_d0d5_11ea_8f4b_94f6d61f3bfelevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_0809daae_d0d5_11ea_8f4b_94f6d61f3bferow0_col0" class="data row0 col0" >SULTANBEYLİ</td>
#                         <td id="T_0809daae_d0d5_11ea_8f4b_94f6d61f3bferow0_col1" class="data row0 col1" >60</td>
#                         <td id="T_0809daae_d0d5_11ea_8f4b_94f6d61f3bferow0_col2" class="data row0 col2" >430</td>
#             </tr>
#             <tr>
#                         <th id="T_0809daae_d0d5_11ea_8f4b_94f6d61f3bfelevel0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_0809daae_d0d5_11ea_8f4b_94f6d61f3bferow1_col0" class="data row1 col0" >GAZİOSMANPAŞA</td>
#                         <td id="T_0809daae_d0d5_11ea_8f4b_94f6d61f3bferow1_col1" class="data row1 col1" >55</td>
#                         <td id="T_0809daae_d0d5_11ea_8f4b_94f6d61f3bferow1_col2" class="data row1 col2" >60</td>
#             </tr>
#             <tr>
#                         <th id="T_0809daae_d0d5_11ea_8f4b_94f6d61f3bfelevel0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_0809daae_d0d5_11ea_8f4b_94f6d61f3bferow2_col0" class="data row2 col0" >BAYRAMPAŞA</td>
#                         <td id="T_0809daae_d0d5_11ea_8f4b_94f6d61f3bferow2_col1" class="data row2 col1" >52.8</td>
#                         <td id="T_0809daae_d0d5_11ea_8f4b_94f6d61f3bferow2_col2" class="data row2 col2" >4252</td>
#             </tr>
#             <tr>
#                         <th id="T_0809daae_d0d5_11ea_8f4b_94f6d61f3bfelevel0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_0809daae_d0d5_11ea_8f4b_94f6d61f3bferow3_col0" class="data row3 col0" >KARTAL</td>
#                         <td id="T_0809daae_d0d5_11ea_8f4b_94f6d61f3bferow3_col1" class="data row3 col1" >47.9</td>
#                         <td id="T_0809daae_d0d5_11ea_8f4b_94f6d61f3bferow3_col2" class="data row3 col2" >2014</td>
#             </tr>
#             <tr>
#                         <th id="T_0809daae_d0d5_11ea_8f4b_94f6d61f3bfelevel0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_0809daae_d0d5_11ea_8f4b_94f6d61f3bferow4_col0" class="data row4 col0" >BEYOĞLU</td>

# %% [markdown]
# parayı da ekle

# %%
df_district_capacity = pd.DataFrame({"location":df_live.groupby("ilce")["kapasitesi"].sum().index,
                                    "capacity":df_live.groupby("ilce")["kapasitesi"].sum().values})
df_district_capacity.head()
# Out:
#        location  capacity
# 0    ARNAVUTKÖY       700
# 1      ATAŞEHİR      2555
# 2       AVCILAR      1370
# 3  BAHÇELİEVLER      1360
# 4      BAKIRKÖY      5087

# %%
df_live.groupby("ilce")["kapasitesi"].sum()
# Out:
# ilce
# ARNAVUTKÖY         700
# ATAŞEHİR          2555
# AVCILAR           1370
# BAHÇELİEVLER      1360
# BAKIRKÖY          5087
# BAYRAMPAŞA        4252
# BAĞCILAR           645
# BAŞAKŞEHİR         355
# BEYKOZ            1103
# BEYLİKDÜZÜ        1570
# BEYOĞLU           3616
# BEŞİKTAŞ          5850
# BÜYÜKÇEKMECE       140
# ESENLER           1694
# EYÜP             15527
# FATİH             6924
# GAZİOSMANPAŞA       60
# GÜNGÖREN          2525
# KADIKÖY           6090
# KARTAL            2014
# KAĞITHANE         3103
# KÜÇÜKÇEKMECE      1387
# MALTEPE           3385
# PENDİK            4238
# SARIYER           7072
# SULTANBEYLİ        430
# SULTANGAZİ         104
# SİLİVRİ            390
# TUZLA              600
# ZEYTİNBURNU       6055
# ÜMRANİYE          1375
# ÜSKÜDAR           2615
# ŞİŞLİ             4078
# Name: kapasitesi, dtype: int64

# %% [markdown]
# This repository has been created for Udacity Data Scientist Nanodegree Program - Write A Data Science Blog Post Project
